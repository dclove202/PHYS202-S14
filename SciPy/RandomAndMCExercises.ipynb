# %% [markdown]
# # Random Numbers, Monte Carlo Sampling and Simulation Exercises

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plot
from IPython.html.widgets import interact, interactive
from scipy.integrate import trapz,cumtrapz
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Question 1

# %% [markdown]
# The Weibull distribution, with parameters α>0 and β>0 is described by the density function
#
# f(x)=                  $f(x) = \alpha \beta^{-\alpha}x^{\alpha - 1} e^{-(x/\beta)^{\alpha}}$                          if x>0
#
#     0                   otherwise

# %% [markdown]
# (a) Solve for the CDF of the Weibull distribution analytically, using
# F(x)=∫x−∞f(t)dt

# %% [markdown]
# Using a U substitution: U = (1/α)*x^α, and integrating with x as the upper bound and 0 as the lower,
# My solution is:
#
# f(x) = $1 - e^{-(x/\beta)^{\alpha}}$

# %% [markdown]
# (b) Find the inverse of the CDF $F^{−1}(x)$ analytically.

# %% [markdown]
# It's inverse, found by substituting f^-1(x) for x and x for f(x) and solving, is:
#
# $f^{-1}(x) = \beta(-ln(1-x))^{1/\alpha}$

# %% [markdown]
# (c) Write a program to generate 10,000 samples from the Weibull distribution and plot the true distribution, the CDF and the sampled distribution as a histogram, all on the same graph. Let
# α = 1.5,
# β = 6.
# Note: Do not use the built-in Weibull function from numpy.random.

# %%
#Functions
alpha = 1.5
beta = 6.0
x = np.arange(0,100,.01)
f = lambda x: alpha*beta**(-alpha) * x**(alpha-1) * np.e**(-(x/beta)**alpha)
F = lambda x: 1 - np.e**(-1*(x/beta)**alpha)
Finv = lambda z: beta*((-1*np.log(1-z))**(1./alpha))

#Plots
plt.plot(x,f(x),linewidth=2,label='True Distribution')
plt.plot(x,F(x),linewidth=2, label='Cumulative Function')
plt.xlim(0,20)
plt.ylim(0,1.1)

#Histogram
N = 10000
z = numpy.random.random_sample(N)
xsamp = Finv(z)
plt.hist(xsamp, 50, normed=True, label="Sampled Distribution")

plt.legend(loc='best',fancybox=True,framealpha=.3)
plt.xlabel(r"$X$", fontsize=20)
plt.ylabel(r'$f(x) = \alpha \beta^{-\alpha}x^{\alpha - 1} e^{-(x/\beta)^{\alpha}}$', fontsize = 15)
plt.show()

# %% [markdown]
# (d) Run the four statistical tests of randomness (mean, variance, chi-square, K-S) on your results from question 1(c). Does it pass all of them?

# %% [markdown]
# ## Question 2

# %% [markdown]
# The Beta(4,3) distribution has density
#
# f(x)={60x^3(1−x)^2 if 0≤x≤1
#
# 0   otherwise
#
# The maximum of this distribution is f(0.6)=2.0736 (exactly).
#
#
# (a) Write a program that uses the Rejection Sampling Method to generate a set of 10,000 samples from this distribution and plot the density distribution, the CDF, and a histogram of the sampled distribution on the same graph.
# Note: Do not use the built-in Beta function from numpy.random.

# %%
x = np.arange(0.,1.001,.001)
xmin = 0.0
xmax = 1.0
f = lambda x: 60*(x**3)*(1-x)**2
F = lambda x: 10*x**6 - 24*x**5 + 15*x**4
N = 10000
subx = x[logical_and((x>xmin),(x<xmax))]
ymax = f(subx).max()*1.05
ymin = 0
samples_x = xmin + (xmax-xmin)*np.random.random_sample(N);
samples_y = ymin + (ymax-ymin)*np.random.random_sample(N);
newmask = (samples_y < f(samples_x))
I = (xmax-xmin)*(ymax-ymin)*newmask.sum()/newmask.size

plt.plot(x,f(x), linewidth = 2)
plt.plot(samples_x[1:500],samples_y[1:500],'g.')
plt.plot(samples_x[newmask[:500]],samples_y[newmask[:500]],'r.')
plt.show()

# %% [markdown]
# ## Question 3

# %% [markdown]
# (a) Plot the Woods-Saxon distribution $\rho$(r) and $r^{2}\rho (r)$ for gold from r = 0 to r = 18 fm.

# %%
rho = lambda r: p0*(1+(w*r**2)/(R**2))/(1+e**((r-R)/a))
#Gold constants
p0 = 1 
#Unsure about value of rho naught constant...
w = 0.
R = 6.38
a = 0.535
r = np.arange(0,18.01,.001)
plt.plot(r, rho(r), label= r'$ \rho (r)$', linewidth = 2)
plt.plot(r,r**2 * rho(r), linewidth=2, label= r'$r^{2}\rho (r)$')
plt.ylabel('Density', fontsize=20)
plt.xlabel('r (fm)', fontsize=20)
plt.legend(loc='best',fancybox=True,framealpha=.4, fontsize=15)
plt.show()
